# %% [markdown]
# ## Imports

# %%
from dotenv import load_dotenv
load_dotenv()
import os
from utils import read_table
from utils import check_uniqueness

# %% [markdown]
# ## Analyzing table

# %%
table_name = os.getenv("SQL_CUSTOMER")
df = read_table(table_name)
df.head()
# Out:
#    CustomerKey  GeoAreaKey     StartDT       EndDT  Continent  Gender Title  \
# 0           15           4  1990-09-10  2034-07-29  Australia    male   Mr.
# 1          180           7  1987-11-26  2026-10-14  Australia    male   Mr.
# 2          185           2  1990-08-01  2029-05-28  Australia  female  Mrs.
# 3          311           7  1989-09-13  2026-08-13  Australia  female  Mrs.
# 4          385           5  2004-11-22  2034-12-17  Australia  female   Ms.
#
#    GivenName MiddleInitial    Surname  ... ZipCode Country CountryFull  \
# 0     Julian             A   McGuigan  ...    4357      AU   Australia
# 1    Gabriel             P  Bosanquet  ...    3505      AU   Australia
# 2  Gabrielle             B   Castella  ...    2469      AU   Australia
# 3      Milla             H     Niland  ...    3525      AU   Australia
# 4      Katie             Z      Oberg  ...    5235      AU   Australia
#
#      Birthday Age                         Occupation             Company  \
# ...

# %% [markdown]
# ## Size of the dataframe

# %%
df.shape
# Out:
# (52189, 24)

# %% [markdown]
# ## Columns of the table

# %%
df.columns.tolist()
# Out:
# ['CustomerKey',
#  'GeoAreaKey',
#  'StartDT',
#  'EndDT',
#  'Continent',
#  'Gender',
#  'Title',
#  'GivenName',
#  'MiddleInitial',
#  'Surname',
#  'StreetAddress',
#  'City',
#  'State',
#  'StateFull',
#  'ZipCode',
#  'Country',
#  'CountryFull',
#  'Birthday',
#  'Age',
#  'Occupation',
#  'Company',
#  'Vehicle',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# ## Overview of the table

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52189 entries, 0 to 52188
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerKey    52189 non-null  int64
#  1   GeoAreaKey     52189 non-null  int64
#  2   StartDT        52189 non-null  object
#  3   EndDT          52189 non-null  object
#  4   Continent      52189 non-null  object
#  5   Gender         52189 non-null  object
#  6   Title          52189 non-null  object
#  7   GivenName      52189 non-null  object
#  8   MiddleInitial  52189 non-null  object
#  9   Surname        52189 non-null  object
#  10  StreetAddress  52189 non-null  object
#  11  City           52189 non-null  object
#  12  State          52189 non-null  object
#  13  StateFull      52189 non-null  object
#  14  ZipCode        52189 non-null  object
#  15  Country        52189 non-null  object
#  16  CountryFull    52189 non-null  object
# ...

# %% [markdown]
# ## Percentage of null values per column

# %%
df.isnull().mean().round(4) * 100
# Out:
# CustomerKey      0.00
# GeoAreaKey       0.00
# StartDT          0.00
# EndDT            0.00
# Continent        0.00
# Gender           0.00
# Title            0.00
# GivenName        0.00
# MiddleInitial    0.00
# Surname          0.00
# StreetAddress    0.00
# City             0.00
# State            0.00
# StateFull        0.00
# ZipCode          0.00
# Country          0.00
# CountryFull      0.00
# Birthday         0.00
# Age              0.00
# Occupation       0.00
# Company          0.09
# Vehicle          0.00
# Latitude         0.00
# Longitude        0.00
# dtype: float64

# %% [markdown]
# ## Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Checking column uniqueness

# %%
check_uniqueness(df)
# Out:
# CustomerKey: Unique
# GeoAreaKey: Not unique
# StartDT: Not unique
# EndDT: Not unique
# Continent: Not unique
# Gender: Not unique
# Title: Not unique
# GivenName: Not unique
# MiddleInitial: Not unique
# Surname: Not unique
# StreetAddress: Not unique
# City: Not unique
# State: Not unique
# StateFull: Not unique
# ZipCode: Not unique
# Country: Not unique
# CountryFull: Not unique
# Birthday: Not unique
# Age: Not unique
# Occupation: Not unique
# Company: Not unique
# Vehicle: Not unique
# Latitude: Not unique
# Longitude: Not unique

# %% [markdown]
# # After analyzing the table, it is evident that CustomerKey serves as the primary key, uniquely identifying each customer
