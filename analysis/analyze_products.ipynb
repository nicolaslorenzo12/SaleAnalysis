# %% [markdown]
# ## Imports

# %%
import pandas as pd
from utils import check_uniqueness

# %% [markdown]
# ## Analyzing table

# %%
products_file_path = "../data/Product.json"

df = pd.read_json(products_file_path)
df.head()
# Out:
#    ProductKey  ProductCode                          ProductName  Manufacturer  \
# 0           1       101001  Contoso 512MB MP3 Player E51 Silver  Contoso, Ltd
# 1           2       101002    Contoso 512MB MP3 Player E51 Blue  Contoso, Ltd
# 2           3       101003     Contoso 1G MP3 Player E100 White  Contoso, Ltd
# 3           4       101004    Contoso 2G MP3 Player E200 Silver  Contoso, Ltd
# 4           5       101005       Contoso 2G MP3 Player E200 Red  Contoso, Ltd
#
#      Brand   Color WeightUnit  Weight   Cost  Price  CategoryKey CategoryName  \
# 0  Contoso  Silver     ounces     4.8   6.62  12.99            1        Audio
# 1  Contoso    Blue     ounces     4.1   6.62  12.99            1        Audio
# 2  Contoso   White     ounces     4.5   7.40  14.52            1        Audio
# 3  Contoso  Silver     ounces     4.5  11.00  21.57            1        Audio
# 4  Contoso     Red     ounces     2.4  11.00  21.57            1        Audio
#
# ...

# %% [markdown]
# ## Size of dataframe

# %%
df.shape
# Out:
# (2517, 14)

# %% [markdown]
# ## Columns of the table

# %%
df.columns.tolist()
# Out:
# ['ProductKey',
#  'ProductCode',
#  'ProductName',
#  'Manufacturer',
#  'Brand',
#  'Color',
#  'WeightUnit',
#  'Weight',
#  'Cost',
#  'Price',
#  'CategoryKey',
#  'CategoryName',
#  'SubCategoryKey',
#  'SubCategoryName']

# %% [markdown]
# ## Overview of the table

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ProductKey       2517 non-null   int64
#  1   ProductCode      2517 non-null   int64
#  2   ProductName      2517 non-null   object
#  3   Manufacturer     2517 non-null   object
#  4   Brand            2517 non-null   object
#  5   Color            2517 non-null   object
#  6   WeightUnit       2295 non-null   object
#  7   Weight           2233 non-null   float64
#  8   Cost             2517 non-null   float64
#  9   Price            2517 non-null   float64
#  10  CategoryKey      2517 non-null   int64
#  11  CategoryName     2517 non-null   object
#  12  SubCategoryKey   2517 non-null   int64
#  13  SubCategoryName  2517 non-null   object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 275.4+ KB

# %% [markdown]
# ## Percentage of null values per column

# %%
df.isnull().mean().round(4) * 100
# Out:
# ProductKey          0.00
# ProductCode         0.00
# ProductName         0.00
# Manufacturer        0.00
# Brand               0.00
# Color               0.00
# WeightUnit          8.82
# Weight             11.28
# Cost                0.00
# Price               0.00
# CategoryKey         0.00
# CategoryName        0.00
# SubCategoryKey      0.00
# SubCategoryName     0.00
# dtype: float64

# %% [markdown]
# ## Checking duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Checking column uniqueness

# %%
check_uniqueness(df)
# Out:
# ProductKey: Unique
# ProductCode: Unique
# ProductName: Unique
# Manufacturer: Not unique
# Brand: Not unique
# Color: Not unique
# WeightUnit: Not unique
# Weight: Not unique
# Cost: Not unique
# Price: Not unique
# CategoryKey: Not unique
# CategoryName: Not unique
# SubCategoryKey: Not unique
# SubCategoryName: Not unique

# %% [markdown]
# # After analyzing the table, it is evident that ProductKey serves as the primary key, uniquely identifying each product
